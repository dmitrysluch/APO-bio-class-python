# %% [markdown]
# <link rel="stylesheet" href="theme.css" id="theme">

# %% [markdown]
# <h2 style="margin: auto; text-align: center">Кто это ваше программирование вообще такое</h2>
# <img alt="Кто это ваше программирование вообще такое" align="center" style="display: block; margin: auto; width:100%; margin-top: 2rem;" src="./computer_problems.png">

# %% [markdown]
# ## Нафига, а главное зачем нужно программирование
# + Посчитать что нибудь несчитаемое - первые компьютеры использовались чтобы решать уравнения, чтобы рассчитывать траектории снарядов
# + Делать что-то скучное постоянно - есть банк, у банка есть процесс который делают ручками. Вжух и он автоматизирован
# + Делать что-то быстро, люди медленные, а пользователи ждать не будут
# + Обрабатывать много данных, у вас есть табличка на несколько терабайт, и с ней надо что-то сделать

# %% [markdown]
# ## А теперь лучшие программисты современности, занимаются тем чтобы заставить пользователя кликнуть на рекламу
# ![yandex direct](yd.png)

# %% [markdown]
# ## Нафига, а главное зачем вам нужно программирование
# + Есть огромное количество удобных инструментов для аналитики - часто написать скрипт быстрее, чем посчитать в том же excel
# + Один раз написал скрипт - можешь как угодно заменять данные, новые результаты появятся мгновенно
# + У программирования выше порог вхождения, но после этого можно реализовать любую функциональность. Если какой-то функциональности нет в Excel то ты проиграл, если чего-то нет в pandas, то это можно написать

# %% [markdown]
# ## Python и другие языки
# <img alt="Кто это ваше программирование вообще такое" align="center" style="display: block; margin: auto; width:100%; margin-top: 2rem;" src="./langs.png">

# %% [markdown]
# ## Не надо учить документацию, всегда можно загуглить)0))

# %% [markdown]
# #### Анализировать, анализировать давай скорее анализировать
# Есть датасет, с статистикой по заболеваемости короновирусом по разным провинциям Индии. Хотим посчитать среднее, дисперсию и построить столбчатую диаграмму. Посчитаем это руками, excel-ем и python-ом, и убедимся что питон всех рвет)0))

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("small_covid.csv")

# %%
df
# Out:
#         State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio (%)  \
# 0     Maharashtra      6489800   51234     6300755  137811              0.79
# 1          Kerala      4227526  239338     3966557   21631              5.66
# 2       Karnataka      2956137   17412     2901299   37426              0.59
# 3      Tamil Nadu      2624234   16256     2572942   35036              0.62
# 4  Andhra Pradesh      2022064   14550     1993589   13925              0.72
#
#    Discharge Ratio (%)  Death Ratio (%)  Total Cases, mln
# 0                97.09             2.12               6.5
# 1                93.83             0.51               4.2
# 2                98.14             1.27               3.0
# 3                98.05             1.34               2.6
# 4                98.59             0.69               2.0

# %% [markdown]
# ## Задавайте вопросы

# %% [markdown]
# ## PyTutor
# потому-что скорее всего на предыдущий матриал уйдет где-то час, а еще пол часа что-то надо делать
# На следующую лекцию останется ввод вывод и типы
# http://pythontutor.ru/lessons/inout_and_arithmetic_operations/
# + print()
# + Арифметика
# + \+ - / * // % **
# + числа по умолчанию длинные
# + строки
# + кавычки '' и ""
# + операции со строками (+ и *)
